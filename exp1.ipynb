# %% [markdown]
# <a href="https://colab.research.google.com/github/A-Thiyagarajan/Ex-1-NN/blob/main/exp1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importing Libraries
import pandas as pd
import io
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

# %%
# Read the dataset
df=pd.read_csv("Churn_Modelling.csv",index_col="RowNumber")
df.head()
# Out:
#            CustomerId   Surname  CreditScore Geography  Gender  Age  Tenure  \
# RowNumber
# 1            15634602  Hargrave          619    France  Female   42       2
# 2            15647311      Hill          608     Spain  Female   41       1
# 3            15619304      Onio          502    France  Female   42       8
# 4            15701354      Boni          699    France  Female   39       1
# 5            15737888  Mitchell          850     Spain  Female   43       2
#
#              Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# RowNumber
# 1               0.00              1          1               1
# 2           83807.86              1          0               1
# 3          159660.80              3          1               0
# 4               0.00              2          0               0
# 5          125510.82              1          1               1
#
#            EstimatedSalary  Exited
# RowNumber
# 1                101348.88       1
# 2                112542.58       0
# 3                113931.57       1
# 4                 93826.63       0
# 5                 79084.10       0

# %%
# Finding Missing Values
df.isnull().sum()
# Out:
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
# Check For Duplicates
df.duplicated().sum()
# Out:
# 0

# %%
# Detect Outliers
df=df.drop(['Surname', 'Geography','Gender'], axis=1)

# %%
# Normalize the dataset
scaler=StandardScaler()
df=pd.DataFrame(scaler.fit_transform(df))
df.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0 -0.783213 -0.326221  0.293517 -1.041760 -1.225848 -0.911583  0.646092
# 1 -0.606534 -0.440036  0.198164 -1.387538  0.117350 -0.911583 -1.547768
# 2 -0.995885 -1.536794  0.293517  1.032908  1.333053  2.527057  0.646092
# 3  0.144767  0.501521  0.007457 -1.387538 -1.225848  0.807737 -1.547768
# 4  0.652659  2.063884  0.388871 -1.041760  0.785728 -0.911583  0.646092
#
#           7         8         9
# 0  0.970243  0.021886  1.977165
# 1  0.970243  0.216534 -0.505775
# 2 -1.030670  0.240687  1.977165
# 3 -1.030670 -0.108918 -0.505775
# 4  0.970243 -0.365276 -0.505775

# %%
# Split the dataset into input and output
X,Y=df.iloc[:,:-1].values ,df.iloc[:,-1].values
print('Input:\n',X,'\nOutput:\n',Y)
# Out:
# Input:
#  [[-0.78321342 -0.32622142  0.29351742 ...  0.64609167  0.97024255
#    0.02188649]
#  [-0.60653412 -0.44003595  0.19816383 ... -1.54776799  0.97024255
#    0.21653375]
#  [-0.99588476 -1.53679418  0.29351742 ...  0.64609167 -1.03067011
#    0.2406869 ]
#  ...
#  [-1.47928179  0.60498839 -0.27860412 ... -1.54776799  0.97024255
#   -1.00864308]
#  [-0.11935577  1.25683526  0.29351742 ...  0.64609167 -1.03067011
#   -0.12523071]
#  [-0.87055909  1.46377078 -1.04143285 ...  0.64609167 -1.03067011
#   -1.07636976]]
# Output:
#  [ 1.97716468 -0.50577476  1.97716468 ...  1.97716468  1.97716468
#  -0.50577476]

# %%
# Splitting the data for training & Testing
Xtrain,Xtest,Ytrain,Ytest = train_test_split(X, Y, test_size=0.2)

# %%
# Print the training data and testing data
print("Xtrain:\n" ,Xtrain, "\nXtest:\n", Xtest)
print("\nYtrain:\n" ,Ytrain, "\nYtest:\n", Ytest)
# Out:
# Xtrain:
#  [[-1.34198658 -0.68835857  0.86563897 ...  0.64609167 -1.03067011
#   -0.43349022]
#  [ 1.31438937  0.52221419  0.00745665 ...  0.64609167  0.97024255
#    0.17308386]
#  [-0.49490182 -1.99205231 -0.37395771 ...  0.64609167 -1.03067011
#    0.61204936]
#  ...
#  [ 1.26911087 -1.34020544 -0.08789694 ...  0.64609167 -1.03067011
#   -0.84573457]
#  [-1.14735991 -0.54350371  0.00745665 ...  0.64609167 -1.03067011
#    1.026648  ]
#  [ 0.6657265   0.82227068  0.5795782  ... -1.54776799 -1.03067011
#    1.08486272]]
# Xtest:
#  [[ 0.89161855  1.31891592 -0.18325053 ...  0.64609167  0.97024255
#    0.58443701]
#  [-0.6093145   1.48446433 -1.61355439 ...  0.64609167  0.97024255
#    0.13324896]
#  [-0.27530733 -1.05049572  1.24705333 ... -1.54776799  0.97024255
#   -1.59029698]
#  ...
#  [-1.48403624  0.55325451 -0.27860412 ... -1.54776799  0.97024255
#    0.0088943 ]
#  [-1.0289991  -1.77477002 -1.23214003 ...  0.64609167  0.97024255
#   -1.40804425]
#  [-0.0998514  -0.10893913  0.4842246  ...  0.64609167 -1.03067011
#   -0.57188076]]
#
# Ytrain:
#  [ 1.97716468 -0.50577476 -0.50577476 ... -0.50577476 -0.50577476
#  -0.50577476]
# Ytest:
#  [ 1.97716468 -0.50577476  1.97716468 ... -0.50577476 -0.50577476
#  -0.50577476]
